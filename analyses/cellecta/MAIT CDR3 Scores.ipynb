# %%
library('tidyverse')
library('ggbeeswarm')

org_opts <- options()

# %%
read_tsv('MAITMATCH_results_20240501.tsv') %>%
    ggplot(aes(x=`Score`)) +
        geom_histogram(binwidth=.001)
# Out:
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details, e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Rows: 176625 Columns: 4
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): Res, Sequence, MAIT_hit
# dbl (1): Score
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Warning message:
# “Removed 3 rows containing non-finite values (`stat_bin()`).”
# plot without title

# %%
read_fwf('MAITMATCH_results_20240501.tsv', fwf_empty('MAITMATCH_results_20240501.tsv', col_names = c("Res Sequence", "MAIT_hit", "Score")), comment='#')
# Out:
# Rows: 176626 Columns: 1
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# chr (1): Res Sequence
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#        Res Sequence
# 1      Res              Sequence             MAIT_hit  Score
# 2      Best              ALGVLHC             CALNDMRF 0.8199
# 3      Best            AGIAYQLIW         CAAIDSNYQLIW 0.8347
# 4      Best              AATKLIF             CALNDMRF 0.8445
# 5      Best       AGCVIQEGADGLTF        CAVLGQAGTALIF 0.8222
# 6      Best          AHIDRDYEQYF         CAVRDRDYKLSF 0.8291
# 7      Best               AMPLMF             CALNDMRF 0.8110
# 8      Best               AQASTF             CALNDMRF 0.8146
# ...

# %%
read_fwf('MAITMATCH_results_20240501.tsv', comment='#')
# Out:
# Rows: 176626 Columns: 1
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# chr (1): X1
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#        X1
# 1      Res              Sequence             MAIT_hit  Score
# 2      Best              ALGVLHC             CALNDMRF 0.8199
# 3      Best            AGIAYQLIW         CAAIDSNYQLIW 0.8347
# 4      Best              AATKLIF             CALNDMRF 0.8445
# 5      Best       AGCVIQEGADGLTF        CAVLGQAGTALIF 0.8222
# 6      Best          AHIDRDYEQYF         CAVRDRDYKLSF 0.8291
# 7      Best               AMPLMF             CALNDMRF 0.8110
# 8      Best               AQASTF             CALNDMRF 0.8146
# 9      Best            ARLWNVLHC             CALNDMRF 0.8056
# ...
