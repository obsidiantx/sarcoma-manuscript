# %%
library('tidyverse')
library('readxl')
library('ggrepel')

library('limma')
library('edgeR')

org_opts <- options()
# Out:
# ── Attaching packages ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0      ✔ purrr   1.0.1
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.3.0      ✔ stringr 1.5.0
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
readxl::excel_sheets('1102025Chondrosarcoma Nanostring Normalized.xlsx')
# Out:
# [1] "Chondrosarcoma Nanostring Norma" "Raw data"
# [3] "1102025Chondrosarcoma Nanostrin"

# %%
qc_tbl <-
    read_xlsx(
        '1102025Chondrosarcoma Nanostring Normalized.xlsx',
        sheet='1102025Chondrosarcoma Nanostrin'
    ) %>%
    rename(`sample_name_simple`=`Sample Name`)
# Out:
# New names:
# • `` -> `...6`

# %%
ns_colnames <-
    read_xlsx(
        '1102025Chondrosarcoma Nanostring Normalized.xlsx',
        sheet='Raw data',
        n_max=1
    ) %>%
    colnames()

ns_colnames
# Out:
#  [1] "Probe Name"
#  [2] "Accession #"
#  [3] "Class Name"
#  [4] "20250102_30102954030325-01_10P_07.RCC"
#  [5] "20250102_30102954030325-01_12T_11.RCC"
#  [6] "20250102_30102954030325-01_16P_05.RCC"
#  [7] "20250102_30102954030325-01_17P_10.RCC"
#  [8] "20250102_30102954030325-01_18P_04.RCC"
#  [9] "20250102_30102954030325-01_2T_02.RCC"
# [10] "20250102_30102954030325-01_3P_03.RCC"
# [11] "20250102_30102954030325-01_6P_06.RCC"
# [12] "20250102_30102954030325-01_6T_08.RCC"
# [13] "20250102_30102954030325-01_8P_09.RCC"
# [14] "20250102_30102954030325-01_9P_01.RCC"
# [15] "20250102_30102954030325-01_panel standard_12.RCC"
# [16] "20250102_30102954060325-01_11P_05.RCC"
# [17] "20250102_30102954060325-01_12P_02.RCC"
# [18] "20250102_30102954060325-01_13P_10.RCC"
# [19] "20250102_30102954060325-01_13T_09.RCC"
# [20] "20250102_30102954060325-01_15T_08.RCC"
# [21] "20250102_30102954060325-01_16T_01.RCC"
# [22] "20250102_30102954060325-01_19P_03.RCC"
# [23] "20250102_30102954060325-01_19T_11.RCC"
# [24] "20250102_30102954060325-01_3T_07.RCC"
# [25] "20250102_30102954060325-01_5T_04.RCC"
# [26] "20250102_30102954060325-01_8T_06.RCC"
# [27] "20250102_30102954060325-01_panel standard_12.RCC"
# [28] "20250103_30102954230325-01_15P_04.RCC"
# [29] "20250103_30102954230325-01_17T_02.RCC"
# [30] "20250103_30102954230325-01_1T_03.RCC"
# [31] "20250103_30102954230325-01_4T_05.RCC"
# [32] "20250103_30102954230325-01_5P_01.RCC"
# [33] "20250103_30102954230325-01_panel standard_06.RCC"

# %%
cnt_wtbl <-
    read_xlsx(
        '1102025Chondrosarcoma Nanostring Normalized.xlsx',
        sheet='Raw data',
        skip=2,
        col_names=ns_colnames
    ) %>%
    select(
        -`20250102_30102954030325-01_panel standard_12.RCC`,
        -`20250102_30102954060325-01_panel standard_12.RCC`, 
        -`20250103_30102954230325-01_panel standard_06.RCC`
    )

cnt_wtbl %>%
    head()
# Out:
#   Probe Name Accession #    Class Name 20250102_30102954030325-01_10P_07.RCC
# 1 A2M        NM_000014.4    Endogenous 4593
# 2 ACVR1C     NM_145259.2    Endogenous   51
# 3 ADAM12     NM_003474.5    Endogenous  172
# 4 ADGRE1     NM_001256252.1 Endogenous   14
# 5 ADM        NM_001124.2    Endogenous  406
# 6 ADORA2A    NM_000675.5    Endogenous   36
#   20250102_30102954030325-01_12T_11.RCC 20250102_30102954030325-01_16P_05.RCC
# 1 27                                    22
# 2 11                                    18
# 3 19                                    15
# 4 15                                    18
# 5 22                                    26
# 6 12                                    10
#   20250102_30102954030325-01_17P_10.RCC 20250102_30102954030325-01_18P_04.RCC
# 1 6                                     16
# 2 5                                      7
# 3 7                                     23
# 4 4                                     11
# 5 6                                     12
# 6 5                                      8
#   20250102_30102954030325-01_2T_02.RCC 20250102_30102954030325-01_3P_03.RCC ⋯
# 1 6406                                 14024                                ⋯
# 2   19                                    30                                ⋯
# 3  934                                   590                                ⋯
# 4   42                                    18                                ⋯
# 5  133                                   313                                ⋯
# 6  105                                    63                                ⋯
#   20250102_30102954060325-01_19P_03.RCC 20250102_30102954060325-01_19T_11.RCC
# 1 344                                   2785
# 2 181                                    208
# 3 267                                   1382
# 4  78                                    166
# 5 107                                    678
# 6  48                                     92
#   20250102_30102954060325-01_3T_07.RCC 20250102_30102954060325-01_5T_04.RCC
# 1 9979                                 45
# 2   12                                  9
# 3  637                                 17
# 4   11                                  8
# 5  136                                 12
# 6   35                                 11
#   20250102_30102954060325-01_8T_06.RCC 20250103_30102954230325-01_15P_04.RCC
# 1 14508                                16
# 2    40                                 8
# 3   849                                18
# 4    23                                 9
# 5    92                                12
# 6    86                                12
#   20250103_30102954230325-01_17T_02.RCC 20250103_30102954230325-01_1T_03.RCC
# 1 10                                    123
# 2  8                                      3
# 3  8                                     30
# 4 14                                     12
# 5  8                                     15
# 6  5                                     35
#   20250103_30102954230325-01_4T_05.RCC 20250103_30102954230325-01_5P_01.RCC
# 1 373                                  43
# 2  20                                   2
# 3  26                                   6
# 4  17                                   4
# 5  34                                  10
# 6  20                                   7

# %%
sample_tbl <-
    tibble(
        `sample_name`=
            cnt_wtbl %>%
            select(-`Probe Name`, -`Accession #`, -`Class Name`) %>%
            colnames()
    ) %>%
    mutate(
        `sample_name_simple`=
            `sample_name` %>%
            str_replace_all('.*-01_', '') %>%
            str_replace_all('_.*', ''),
        `sample_id`=str_replace_all(`sample_name_simple`, '[PT]', ''),
        `sample_type`=str_replace_all(`sample_name_simple`, '[0-9]', ''),
    ) %>%
    left_join(qc_tbl, by='sample_name_simple')

sample_tbl
# Out:
#    sample_name                           sample_name_simple sample_id
# 1  20250102_30102954030325-01_10P_07.RCC 10P                10
# 2  20250102_30102954030325-01_12T_11.RCC 12T                12
# 3  20250102_30102954030325-01_16P_05.RCC 16P                16
# 4  20250102_30102954030325-01_17P_10.RCC 17P                17
# 5  20250102_30102954030325-01_18P_04.RCC 18P                18
# 6  20250102_30102954030325-01_2T_02.RCC  2T                 2
# 7  20250102_30102954030325-01_3P_03.RCC  3P                 3
# 8  20250102_30102954030325-01_6P_06.RCC  6P                 6
# 9  20250102_30102954030325-01_6T_08.RCC  6T                 6
# 10 20250102_30102954030325-01_8P_09.RCC  8P                 8
# 11 20250102_30102954030325-01_9P_01.RCC  9P                 9
# 12 20250102_30102954060325-01_11P_05.RCC 11P                11
# 13 20250102_30102954060325-01_12P_02.RCC 12P                12
# 14 20250102_30102954060325-01_13P_10.RCC 13P                13
# 15 20250102_30102954060325-01_13T_09.RCC 13T                13
# 16 20250102_30102954060325-01_15T_08.RCC 15T                15
# 17 20250102_30102954060325-01_16T_01.RCC 16T                16
# 18 20250102_30102954060325-01_19P_03.RCC 19P                19
# 19 20250102_30102954060325-01_19T_11.RCC 19T                19
# 20 20250102_30102954060325-01_3T_07.RCC  3T                 3
# 21 20250102_30102954060325-01_5T_04.RCC  5T                 5
# 22 20250102_30102954060325-01_8T_06.RCC  8T                 8
# 23 20250103_30102954230325-01_15P_04.RCC 15P                15
# 24 20250103_30102954230325-01_17T_02.RCC 17T                17
# 25 20250103_30102954230325-01_1T_03.RCC  1T                 1
# 26 20250103_30102954230325-01_4T_05.RCC  4T                 4
# 27 20250103_30102954230325-01_5P_01.RCC  5P                 5
#    sample_type Sample ID Qubit Est. TS Yield (ng) ...6    DV300 % Rec. Input
# 1  P           116378    106.0    NA   2968.000   106.000 5.18    1000
# 2  T           116381      0.0 0.290      8.120     0.290 n/a       NA
# 3  P           116390      0.0 1.180     33.040     1.180 14.96    500
# 4  P           116392      0.0 0.105      2.940     0.105 26.28    175
# 5  P           116394      0.0 0.085      2.380     0.085 31.22    175
# 6  T           116361     45.2    NA   1265.600    45.200 8.31     500
# 7  P           116364    165.0    NA   4620.000   165.000 15.97    250
# 8  P           116370    158.0    NA   4424.000   158.000 10.18    500
# 9  T           116369     96.2    NA   2693.600    96.200 7.51    1000
# 10 P           116374     72.8    NA   2038.400    72.800 8.67     500
# 11 P           116376     86.8    NA   2430.400    86.800 6.77    1000
# 12 P           116380    188.0    NA   5264.000   188.000 5.93    1000
# 13 P           116382      0.0 1.280     35.840     1.280 5.74    1000
# 14 P           116384      0.0 0.099      2.772     0.099 27.6     175
# 15 T           116383      0.0 0.097      2.716     0.097 26.5     175
# 16 T           116387      0.0 0.137      3.836     0.137 25.54    175
# 17 T           116389      0.0 0.141      3.948     0.141 21.29    250
# 18 P           116396     35.2    NA    985.600    35.200 47.7     125
# 19 T           116395     51.0    NA   1428.000    51.000 n/a       NA
# 20 T           116363    147.0    NA   4116.000   147.000 20.69    250
# 21 T           116367      0.0 0.132      3.696     0.132 22.84    250
# 22 T           116373     31.6    NA    884.800    31.600 5.41    1000
# 23 P           116388      0.0 0.089      2.492     0.089 26.85    175
# 24 T           116391      0.0 0.212      5.936     0.212 15.73    250
# 25 T           116359      0.0 0.366     10.248     0.366 40.26    125
# 26 T           116365      8.2    NA    229.600     8.200 8.56     500
# 27 P           116368      0.0 0.097      2.716     0.097 27.65    175
#    Volume
# 1     9.433962
# 2     0.000000
# 3   423.728814
# 4  1666.666667
# 5  2058.823529
# 6    11.061947
# 7     1.515152
# 8     3.164557
# 9    10.395010
# 10    6.868132
# 11   11.520737
# 12    5.319149
# 13  781.250000
# 14 1767.676768
# 15 1804.123711
# 16 1277.372263
# 17 1773.049645
# 18    3.551136
# 19    0.000000
# 20    1.700680
# 21 1893.939394
# 22   31.645570
# 23 1966.292135
# 24 1179.245283
# 25  341.530055
# 26   60.975610
# 27 1804.123711

# %%
cnt_mtx <-
    cnt_wtbl %>%
    (function(x) {
        x_mtx <-
            x %>%
            select(-`Probe Name`, -`Accession #`, -`Class Name`) %>%
            as.matrix()
        
        rownames(x_mtx) <-
            x %>%
            select(`Probe Name`) %>%
            pull()
        
        x_mtx[, sample_tbl$`sample_name`]
    })

cnt_mtx
# Out:
#          20250102_30102954030325-01_10P_07.RCC
# A2M       4593
# ACVR1C      51
# ADAM12     172
# ADGRE1      14
# ADM        406
# ADORA2A     36
# AKT1      1746
# ALDOA    17160
# ALDOC      453
# ANGPT1     313
# ANGPT2     214
# ANGPTL4   1324
# ANLN       232
# APC        447
# APH1B       28
# API5       685
# APLNR      319
# APOE      1993
# APOL6      157
# AQP9        42
# AREG        57
# ARG1        13
# ARG2        87
# ARID1A     361
# ARNT2      165
# ATF3       360
# ATM        601
# AXIN1      172
# AXL        733
# B2M      14515
# ⋮        ⋮
# GUSB       557
# MRPL19     356
# NRDE2      186
# OAZ1      1976
# POLR2A     869
# PSMC4      382
# PUM1       552
# SDHA      1002
# SF3A1      840
# STK11IP    178
# TBC1D10B   120
# TBP        134
# TFRC       833
# TLK2       294
# TMUB2      511
# UBB       7453
# NEG_A       10
# NEG_B        4
# NEG_C        4
# NEG_D        5
# NEG_E       17
# NEG_F       14
# NEG_G       10
# NEG_H        8
# POS_A    26061
# POS_B    11174
# POS_C     2547
# POS_D      668
# POS_E      118
# POS_F       68
#          20250102_30102954030325-01_12T_11.RCC
# A2M       27
# ACVR1C    11
# ADAM12    19
# ADGRE1    15
# ADM       22
# ADORA2A   12
# AKT1      25
# ALDOA     82
# ALDOC     14
# ANGPT1     5
# ANGPT2     4
# ANGPTL4    5
# ANLN      15
# APC       17
# APH1B      5
# API5      20
# APLNR     12
# APOE      30
# APOL6     12
# AQP9       7
# AREG       6
# ARG1       6
# ARG2      10
# ARID1A    14
# ARNT2     10
# ATF3      11
# ATM       27
# AXIN1      7
# AXL       15
# B2M      248
# ⋮        ⋮
# GUSB         8
# MRPL19      15
# NRDE2        9
# OAZ1        17
# POLR2A      24
# PSMC4        7
# PUM1        16
# SDHA        21
# SF3A1        8
# STK11IP      4
# TBC1D10B     5
# TBP          6
# TFRC        18
# TLK2        16
# TMUB2       10
# UBB        110
# NEG_A       13
# NEG_B        3
# NEG_C        1
# NEG_D        6
# NEG_E       13
# NEG_F        5
# NEG_G        7
# NEG_H        3
# POS_A    26352
# POS_B    13035
# POS_C     2979
# POS_D      663
# POS_E      139
# POS_F       69
#          20250102_30102954030325-01_16P_05.RCC
# A2M       22
# ACVR1C    18
# ADAM12    15
# ADGRE1    18
# ADM       26
# ADORA2A   10
# AKT1      23
# ALDOA     78
# ALDOC     19
# ANGPT1    12
# ANGPT2     4
# ANGPTL4   14
# ANLN       8
# APC       20
# APH1B      6
# API5      34
# APLNR      9
# APOE      82
# APOL6      5
# AQP9      13
# AREG       5
# ARG1       5
# ARG2       9
# ARID1A     9
# ARNT2      9
# ATF3       9
# ATM       28
# AXIN1      5
# AXL        9
# B2M      330
# ⋮        ⋮
# GUSB        11
# MRPL19      17
# NRDE2        7
# OAZ1        31
# POLR2A      18
# PSMC4       19
# PUM1        13
# SDHA        20
# SF3A1       13
# STK11IP      8
# TBC1D10B     3
# TBP          7
# TFRC        28
# TLK2        11
# TMUB2       27
# UBB        123
# NEG_A       26
# NEG_B       17
# NEG_C        7
# NEG_D        3
# NEG_E       11
# NEG_F       14
# NEG_G        7
# NEG_H        6
# POS_A    38296
# POS_B    19860
# POS_C     4432
# POS_D      933
# POS_E      186
# POS_F      102
#          20250102_30102954030325-01_17P_10.RCC
# A2M       6
# ACVR1C    5
# ADAM12    7
# ADGRE1    4
# ADM       6
# ADORA2A   5
# AKT1      5
# ALDOA     9
# ALDOC     2
# ANGPT1    2
# ANGPT2    2
# ANGPTL4   6
# ANLN      1
# APC       3
# APH1B     4
# API5      3
# APLNR     2
# APOE      6
# APOL6     2
# AQP9      9
# AREG      6
# ARG1      1
# ARG2      2
# ARID1A    3
# ARNT2     4
# ATF3      9
# ATM       5
# AXIN1     2
# AXL       6
# B2M      19
# ⋮        ⋮
# GUSB         9
# MRPL19       6
# NRDE2        4
# OAZ1         3
# POLR2A       2
# PSMC4        9
# PUM1         5
# SDHA         3
# SF3A1        2
# STK11IP      3
# TBC1D10B     1
# TBP          4
# TFRC        12
# TLK2         3
# TMUB2        7
# UBB         10
# NEG_A        9
# NEG_B        2
# NEG_C        3
# NEG_D        1
# NEG_E       10
# NEG_F        8
# NEG_G        3
# NEG_H        1
# POS_A    22803
# POS_B     9986
# POS_C     2632
# POS_D      594
# POS_E      102
# POS_F       63
#          20250102_30102954030325-01_18P_04.RCC
# A2M       16
# ACVR1C     7
# ADAM12    23
# ADGRE1    11
# ADM       12
# ADORA2A    8
# AKT1      12
# ALDOA     53
# ALDOC      4
# ANGPT1    10
# ANGPT2     2
# ANGPTL4    6
# ANLN       3
# APC        9
# APH1B      3
# API5      12
# APLNR      5
# APOE      20
# APOL6      4
# AQP9      10
# AREG       1
# ARG1       8
# ARG2      14
# ARID1A     8
# ARNT2      8
# ATF3      14
# ATM       21
# AXIN1      1
# AXL        5
# B2M      246
# ⋮        ⋮
# GUSB         5
# MRPL19      12
# NRDE2        4
# OAZ1        17
# POLR2A       9
# PSMC4        6
# PUM1         4
# SDHA         3
# SF3A1       10
# STK11IP      7
# TBC1D10B     3
# TBP          7
# TFRC        23
# TLK2         5
# TMUB2        7
# UBB         67
# NEG_A       15
# NEG_B        2
# NEG_C        2
# NEG_D        3
# NEG_E        9
# NEG_F       14
# NEG_G        1
# NEG_H        5
# POS_A    29945
# POS_B    13404
# POS_C     3272
# POS_D      779
# POS_E      129
# POS_F       59
#          20250102_30102954030325-01_2T_02.RCC
# A2M       6406
# ACVR1C      19
# ADAM12     934
# ADGRE1      42
# ADM        133
# ADORA2A    105
# AKT1      2199
# ALDOA     9075
# ALDOC      307
# ANGPT1     211
# ANGPT2     219
# ANGPTL4    283
# ANLN       408
# APC        567
# APH1B       51
# API5       869
# APLNR     1116
# APOE      4439
# APOL6      208
# AQP9        83
# AREG        13
# ARG1        20
# ARG2        55
# ARID1A     475
# ARNT2       55
# ATF3       100
# ATM        605
# AXIN1      127
# AXL        863
# B2M      20746
# ⋮        ⋮
# GUSB       483
# MRPL19     245
# NRDE2      131
# OAZ1      3606
# POLR2A    1287
# PSMC4      550
# PUM1       431
# SDHA       658
# SF3A1      702
# STK11IP    104
# TBC1D10B   260
# TBP        177
# TFRC       743
# TLK2       322
# TMUB2      353
# UBB      10559
# NEG_A       12
# NEG_B        2
# NEG_C        4
# NEG_D        4
# NEG_E       15
# NEG_F        9
# NEG_G        6
# NEG_H        6
# POS_A    21912
# POS_B     9425
# POS_C     2046
# POS_D      540
# POS_E      131
# POS_F       51
#          20250102_30102954030325-01_3P_03.RCC
# A2M      14024
# ACVR1C      30
# ADAM12     590
# ADGRE1      18
# ADM        313
# ADORA2A     63
# AKT1      2098
# ALDOA    17323
# ALDOC      206
# ANGPT1     155
# ANGPT2     506
# ANGPTL4    961
# ANLN       543
# APC        516
# APH1B       35
# API5       766
# APLNR      186
# APOE      2506
# APOL6      462
# AQP9        34
# AREG        48
# ARG1        28
# ARG2       397
# ARID1A     337
# ARNT2       59
# ATF3       383
# ATM        663
# AXIN1      155
# AXL        748
# B2M      23480
# ⋮        ⋮
# GUSB       800
# MRPL19     335
# NRDE2      129
# OAZ1      2321
# POLR2A    2516
# PSMC4      303
# PUM1       430
# SDHA       742
# SF3A1      943
# STK11IP    221
# TBC1D10B   256
# TBP        209
# TFRC       798
# TLK2       222
# TMUB2      410
# UBB       7802
# NEG_A       12
# NEG_B        3
# NEG_C        1
# NEG_D        6
# NEG_E       17
# NEG_F       13
# NEG_G        3
# NEG_H       12
# POS_A    25586
# POS_B    11249
# POS_C     2688
# POS_D      664
# POS_E      132
# POS_F       61
#          20250102_30102954030325-01_6P_06.RCC
# A2M       908
# ACVR1C     34
# ADAM12    735
# ADGRE1     20
# ADM        38
# ADORA2A    35
# AKT1     1388
# ALDOA    7087
# ALDOC     564
# ANGPT1    111
# ANGPT2     61
# ANGPTL4   232
# ANLN      344
# APC       844
# APH1B      48
# API5      649
# APLNR      96
# APOE      288
# APOL6      34
# AQP9       26
# AREG       17
# ARG1       37
# ARG2      110
# ARID1A    284
# ARNT2     133
# ATF3      308
# ATM      1281
# AXIN1     158
# AXL       581
# B2M      5591
# ⋮        ⋮
# GUSB       385
# MRPL19     325
# NRDE2      225
# OAZ1      2058
# POLR2A     900
# PSMC4      303
# PUM1       443
# SDHA       834
# SF3A1      744
# STK11IP    139
# TBC1D10B   112
# TBP        164
# TFRC      1929
# TLK2       413
# TMUB2      536
# UBB       6186
# NEG_A       14
# NEG_B        5
# NEG_C        2
# NEG_D        2
# NEG_E       11
# NEG_F       54
# NEG_G        2
# NEG_H        6
# POS_A    23353
# POS_B    10421
# POS_C     2332
# POS_D      603
# POS_E      118
# POS_F       62
#          20250102_30102954030325-01_6T_08.RCC
# A2M       3027
# ACVR1C      27
# ADAM12    1152
# ADGRE1       8
# ADM        356
# ADORA2A     43
# AKT1      2398
# ALDOA    10607
# ALDOC      753
# ANGPT1     284
# ANGPT2     222
# ANGPTL4    442
# ANLN       330
# APC        796
# APH1B       55
# API5       964
# APLNR      244
# APOE      1136
# APOL6      131
# AQP9        28
# AREG        33
# ARG1        26
# ARG2        80
# ARID1A     495
# ARNT2      158
# ATF3       856
# ATM       1356
# AXIN1      198
# AXL       1133
# B2M      13343
# ⋮        ⋮
# GUSB       475
# MRPL19     454
# NRDE2      234
# OAZ1      2514
# POLR2A    1206
# PSMC4      436
# PUM1       676
# SDHA      1196
# SF3A1     1133
# STK11IP    174
# TBC1D10B   185
# TBP        223
# TFRC      3308
# TLK2       510
# TMUB2      586
# UBB       9532
# NEG_A       12
# NEG_B        5
# NEG_C        4
# NEG_D        8
# NEG_E       13
# NEG_F       26
# NEG_G       11
# NEG_H        6
# POS_A    17429
# POS_B     7651
# POS_C     1762
# POS_D      435
# POS_E       79
# POS_F       45
#          20250102_30102954030325-01_8P_09.RCC ⋯
# A2M       9967                                ⋯
# ACVR1C      49                                ⋯
# ADAM12     629                                ⋯
# ADGRE1      40                                ⋯
# ADM        104                                ⋯
# ADORA2A     74                                ⋯
# AKT1      1772                                ⋯
# ALDOA     9282                                ⋯
# ALDOC      313                                ⋯
# ANGPT1     102                                ⋯
# ANGPT2     190                                ⋯
# ANGPTL4    130                                ⋯
# ANLN       284                                ⋯
# APC       1023                                ⋯
# APH1B       39                                ⋯
# API5      1041                                ⋯
# APLNR      810                                ⋯
# APOE      1443                                ⋯
# APOL6      199                                ⋯
# AQP9        71                                ⋯
# AREG         2                                ⋯
# ARG1        64                                ⋯
# ARG2       127                                ⋯
# ARID1A     431                                ⋯
# ARNT2      146                                ⋯
# ATF3        88                                ⋯
# ATM        683                                ⋯
# AXIN1      200                                ⋯
# AXL        946                                ⋯
# B2M      10233                                ⋯
# ⋮        ⋮                                    ⋱
# GUSB       463                                ⋯
# MRPL19     299                                ⋯
# NRDE2      256                                ⋯
# OAZ1      1999                                ⋯
# POLR2A    1382                                ⋯
# PSMC4      399                                ⋯
# PUM1       737                                ⋯
# SDHA      1068                                ⋯
# SF3A1      884                                ⋯
# STK11IP    209                                ⋯
# TBC1D10B   253                                ⋯
# TBP        236                                ⋯
# TFRC       633                                ⋯
# TLK2       317                                ⋯
# TMUB2      406                                ⋯
# UBB       6280                                ⋯
# NEG_A       18                                ⋯
# NEG_B        5                                ⋯
# NEG_C        5                                ⋯
# NEG_D        3                                ⋯
# NEG_E       13                                ⋯
# NEG_F        7                                ⋯
# NEG_G        3                                ⋯
# NEG_H        5                                ⋯
# POS_A    23050                                ⋯
# POS_B     9999                                ⋯
# POS_C     2331                                ⋯
# POS_D      543                                ⋯
# POS_E      125                                ⋯
# POS_F       63                                ⋯
#          20250102_30102954060325-01_19P_03.RCC
# A2M       344
# ACVR1C    181
# ADAM12    267
# ADGRE1     78
# ADM       107
# ADORA2A    48
# AKT1      586
# ALDOA    2786
# ALDOC     207
# ANGPT1    176
# ANGPT2    161
# ANGPTL4  2139
# ANLN      202
# APC       399
# APH1B      31
# API5      582
# APLNR     204
# APOE       48
# APOL6      19
# AQP9      129
# AREG        4
# ARG1      144
# ARG2      204
# ARID1A     83
# ARNT2     129
# ATF3      595
# ATM       199
# AXIN1     117
# AXL        87
# B2M       620
# ⋮        ⋮
# GUSB        98
# MRPL19     134
# NRDE2      159
# OAZ1       508
# POLR2A     470
# PSMC4       70
# PUM1       150
# SDHA       414
# SF3A1      149
# STK11IP     41
# TBC1D10B   136
# TBP        100
# TFRC       257
# TLK2       239
# TMUB2      187
# UBB       2154
# NEG_A       11
# NEG_B        3
# NEG_C        1
# NEG_D        3
# NEG_E       25
# NEG_F       15
# NEG_G        4
# NEG_H        5
# POS_A    31314
# POS_B    12678
# POS_C     3025
# POS_D      804
# POS_E      160
# POS_F       76
#          20250102_30102954060325-01_19T_11.RCC
# A2M       2785
# ACVR1C     208
# ADAM12    1382
# ADGRE1     166
# ADM        678
# ADORA2A     92
# AKT1      2183
# ALDOA    12251
# ALDOC      503
# ANGPT1     288
# ANGPT2     859
# ANGPTL4   5951
# ANLN       794
# APC       1107
# APH1B       56
# API5      1124
# APLNR     1820
# APOE       810
# APOL6      110
# AQP9       359
# AREG        61
# ARG1       256
# ARG2       338
# ARID1A     350
# ARNT2      277
# ATF3      2789
# ATM        592
# AXIN1      211
# AXL        930
# B2M       5735
# ⋮        ⋮
# GUSB       494
# MRPL19     340
# NRDE2      272
# OAZ1      1924
# POLR2A    1749
# PSMC4      241
# PUM1       496
# SDHA       929
# SF3A1      656
# STK11IP     88
# TBC1D10B   365
# TBP        293
# TFRC       788
# TLK2       378
# TMUB2      472
# UBB       6745
# NEG_A       14
# NEG_B        1
# NEG_C        4
# NEG_D       10
# NEG_E       22
# NEG_F       18
# NEG_G        8
# NEG_H        5
# POS_A    27601
# POS_B    11347
# POS_C     2500
# POS_D      719
# POS_E      134
# POS_F       79
#          20250102_30102954060325-01_3T_07.RCC
# A2M       9979
# ACVR1C      12
# ADAM12     637
# ADGRE1      11
# ADM        136
# ADORA2A     35
# AKT1      1700
# ALDOA     7189
# ALDOC       54
# ANGPT1     199
# ANGPT2     248
# ANGPTL4    212
# ANLN       507
# APC        394
# APH1B       39
# API5       770
# APLNR      361
# APOE      3745
# APOL6      329
# AQP9        20
# AREG        80
# ARG1        13
# ARG2       143
# ARID1A     362
# ARNT2       66
# ATF3       223
# ATM        512
# AXIN1      100
# AXL        659
# B2M      21773
# ⋮        ⋮
# GUSB       636
# MRPL19     272
# NRDE2      147
# OAZ1      2315
# POLR2A    1633
# PSMC4      298
# PUM1       416
# SDHA       598
# SF3A1      737
# STK11IP    124
# TBC1D10B   201
# TBP        166
# TFRC       760
# TLK2       238
# TMUB2      320
# UBB      10491
# NEG_A        8
# NEG_B        4
# NEG_C        3
# NEG_D        8
# NEG_E        8
# NEG_F        5
# NEG_G        4
# NEG_H        7
# POS_A    18078
# POS_B     7480
# POS_C     1970
# POS_D      464
# POS_E       88
# POS_F       46
#          20250102_30102954060325-01_5T_04.RCC
# A2M       45
# ACVR1C     9
# ADAM12    17
# ADGRE1     8
# ADM       12
# ADORA2A   11
# AKT1      26
# ALDOA     81
# ALDOC     12
# ANGPT1    13
# ANGPT2     3
# ANGPTL4   14
# ANLN       4
# APC       15
# APH1B      3
# API5      25
# APLNR      7
# APOE      51
# APOL6     16
# AQP9       4
# AREG       4
# ARG1       8
# ARG2       5
# ARID1A     8
# ARNT2      4
# ATF3       8
# ATM       15
# AXIN1      3
# AXL       14
# B2M      415
# ⋮        ⋮
# GUSB        10
# MRPL19      10
# NRDE2        6
# OAZ1        28
# POLR2A      25
# PSMC4        9
# PUM1        11
# SDHA        14
# SF3A1       16
# STK11IP      3
# TBC1D10B     9
# TBP          9
# TFRC        21
# TLK2        11
# TMUB2       12
# UBB        161
# NEG_A        5
# NEG_B        4
# NEG_C        4
# NEG_D        2
# NEG_E        3
# NEG_F        6
# NEG_G        1
# NEG_H        4
# POS_A    25038
# POS_B    11209
# POS_C     2802
# POS_D      728
# POS_E      144
# POS_F       64
#          20250102_30102954060325-01_8T_06.RCC
# A2M      14508
# ACVR1C      40
# ADAM12     849
# ADGRE1      23
# ADM         92
# ADORA2A     86
# AKT1      2445
# ALDOA    24431
# ALDOC      780
# ANGPT1      63
# ANGPT2     134
# ANGPTL4    987
# ANLN       464
# APC       1172
# APH1B       53
# API5      1412
# APLNR      387
# APOE      1634
# APOL6       51
# AQP9        31
# AREG         8
# ARG1        19
# ARG2       274
# ARID1A     757
# ARNT2      104
# ATF3       121
# ATM        749
# AXIN1      248
# AXL        560
# B2M      10158
# ⋮        ⋮
# GUSB       607
# MRPL19     299
# NRDE2      300
# OAZ1      3396
# POLR2A    1100
# PSMC4      559
# PUM1      1099
# SDHA      1363
# SF3A1     1080
# STK11IP    310
# TBC1D10B   199
# TBP        259
# TFRC       907
# TLK2       306
# TMUB2      529
# UBB       6153
# NEG_A       14
# NEG_B        3
# NEG_C        2
# NEG_D        5
# NEG_E       13
# NEG_F        9
# NEG_G        2
# NEG_H        7
# POS_A    27220
# POS_B    11131
# POS_C     2483
# POS_D      696
# POS_E      128
# POS_F       48
#          20250103_30102954230325-01_15P_04.RCC
# A2M       16
# ACVR1C     8
# ADAM12    18
# ADGRE1     9
# ADM       12
# ADORA2A   12
# AKT1      16
# ALDOA     32
# ALDOC     16
# ANGPT1     5
# ANGPT2     6
# ANGPTL4    9
# ANLN       6
# APC       13
# APH1B      7
# API5      18
# APLNR      8
# APOE      28
# APOL6     10
# AQP9      14
# AREG       6
# ARG1       6
# ARG2      13
# ARID1A     6
# ARNT2      6
# ATF3      31
# ATM       18
# AXIN1      4
# AXL       10
# B2M      150
# ⋮        ⋮
# GUSB         9
# MRPL19      14
# NRDE2        9
# OAZ1        10
# POLR2A       9
# PSMC4        8
# PUM1         6
# SDHA         9
# SF3A1        6
# STK11IP      6
# TBC1D10B    11
# TBP         11
# TFRC        17
# TLK2         9
# TMUB2       10
# UBB         48
# NEG_A       19
# NEG_B        6
# NEG_C        7
# NEG_D        5
# NEG_E       10
# NEG_F       15
# NEG_G        7
# NEG_H       10
# POS_A    31107
# POS_B    14341
# POS_C     3390
# POS_D      787
# POS_E      123
# POS_F       71
#          20250103_30102954230325-01_17T_02.RCC
# A2M       10
# ACVR1C     8
# ADAM12     8
# ADGRE1    14
# ADM        8
# ADORA2A    5
# AKT1       8
# ALDOA     24
# ALDOC     12
# ANGPT1     7
# ANGPT2     3
# ANGPTL4    6
# ANLN       6
# APC        7
# APH1B      4
# API5      14
# APLNR      3
# APOE      30
# APOL6      7
# AQP9       7
# AREG       6
# ARG1       6
# ARG2      13
# ARID1A     9
# ARNT2      1
# ATF3      14
# ATM       11
# AXIN1      4
# AXL        9
# B2M      155
# ⋮        ⋮
# GUSB        13
# MRPL19       3
# NRDE2        4
# OAZ1        21
# POLR2A       5
# PSMC4       11
# PUM1         8
# SDHA        10
# SF3A1       10
# STK11IP      2
# TBC1D10B     5
# TBP          6
# TFRC         7
# TLK2         3
# TMUB2       15
# UBB         41
# NEG_A       15
# NEG_B        7
# NEG_C        3
# NEG_D        2
# NEG_E        6
# NEG_F       11
# NEG_G        4
# NEG_H        8
# POS_A    31758
# POS_B    13829
# POS_C     3292
# POS_D      771
# POS_E      163
# POS_F       81
#          20250103_30102954230325-01_1T_03.RCC
# A2M       123
# ACVR1C      3
# ADAM12     30
# ADGRE1     12
# ADM        15
# ADORA2A    35
# AKT1      159
# ALDOA     486
# ALDOC      48
# ANGPT1     13
# ANGPT2     10
# ANGPTL4    13
# ANLN       14
# APC        88
# APH1B       7
# API5      187
# APLNR       8
# APOE      733
# APOL6      84
# AQP9       23
# AREG        8
# ARG1        9
# ARG2        7
# ARID1A     81
# ARNT2      19
# ATF3       26
# ATM       319
# AXIN1      19
# AXL        13
# B2M      4906
# ⋮        ⋮
# GUSB        42
# MRPL19      31
# NRDE2       39
# OAZ1       434
# POLR2A     171
# PSMC4       45
# PUM1        68
# SDHA       118
# SF3A1      137
# STK11IP     12
# TBC1D10B    23
# TBP         29
# TFRC       125
# TLK2        37
# TMUB2       42
# UBB       1366
# NEG_A       15
# NEG_B        7
# NEG_C        6
# NEG_D       12
# NEG_E       13
# NEG_F       10
# NEG_G        9
# NEG_H        6
# POS_A    28195
# POS_B    12987
# POS_C     3026
# POS_D      730
# POS_E      154
# POS_F       72
#          20250103_30102954230325-01_4T_05.RCC
# A2M       373
# ACVR1C     20
# ADAM12     26
# ADGRE1     17
# ADM        34
# ADORA2A    20
# AKT1      107
# ALDOA     436
# ALDOC      49
# ANGPT1     26
# ANGPT2     23
# ANGPTL4    26
# ANLN       25
# APC        61
# APH1B       4
# API5       92
# APLNR      29
# APOE      291
# APOL6      42
# AQP9       17
# AREG        6
# ARG1       11
# ARG2       27
# ARID1A     46
# ARNT2      23
# ATF3       39
# ATM        95
# AXIN1      13
# AXL        35
# B2M      2220
# ⋮        ⋮
# GUSB        35
# MRPL19      24
# NRDE2       36
# OAZ1       173
# POLR2A     109
# PSMC4       28
# PUM1        58
# SDHA        60
# SF3A1       59
# STK11IP     10
# TBC1D10B    30
# TBP         22
# TFRC        71
# TLK2        27
# TMUB2       32
# UBB        652
# NEG_A       18
# NEG_B        7
# NEG_C        5
# NEG_D        4
# NEG_E       16
# NEG_F       10
# NEG_G       10
# NEG_H        7
# POS_A    35788
# POS_B    15908
# POS_C     3706
# POS_D      815
# POS_E      172
# POS_F       77
#          20250103_30102954230325-01_5P_01.RCC
# A2M      43
# ACVR1C    2
# ADAM12    6
# ADGRE1    4
# ADM      10
# ADORA2A   7
# AKT1     10
# ALDOA    46
# ALDOC     2
# ANGPT1    6
# ANGPT2    2
# ANGPTL4   4
# ANLN      2
# APC       4
# APH1B     4
# API5     13
# APLNR     2
# APOE     30
# APOL6     6
# AQP9      3
# AREG      3
# ARG1      3
# ARG2      4
# ARID1A    4
# ARNT2     3
# ATF3     10
# ATM      11
# AXIN1     3
# AXL       3
# B2M      96
# ⋮        ⋮
# GUSB         9
# MRPL19       5
# NRDE2        4
# OAZ1        21
# POLR2A       8
# PSMC4        3
# PUM1         4
# SDHA         7
# SF3A1        4
# STK11IP      1
# TBC1D10B     4
# TBP          7
# TFRC         7
# TLK2         6
# TMUB2        2
# UBB         59
# NEG_A        5
# NEG_B        2
# NEG_C        1
# NEG_D        1
# NEG_E       14
# NEG_F        5
# NEG_G        1
# NEG_H        2
# POS_A    15708
# POS_B     6865
# POS_C     1758
# POS_D      402
# POS_E       81
# POS_F       43

# %%
exp_model <-
    sample_tbl %>%
    model.matrix(data=., ~`sample_type`*`Yield (ng)`)

exp_model
# Out:
#    (Intercept) sample_typeT `Yield (ng)` sample_typeT:`Yield (ng)`
# 1  1           0            2968.000        0.000
# 2  1           1               8.120        8.120
# 3  1           0              33.040        0.000
# 4  1           0               2.940        0.000
# 5  1           0               2.380        0.000
# 6  1           1            1265.600     1265.600
# 7  1           0            4620.000        0.000
# 8  1           0            4424.000        0.000
# 9  1           1            2693.600     2693.600
# 10 1           0            2038.400        0.000
# 11 1           0            2430.400        0.000
# 12 1           0            5264.000        0.000
# 13 1           0              35.840        0.000
# 14 1           0               2.772        0.000
# 15 1           1               2.716        2.716
# 16 1           1               3.836        3.836
# 17 1           1               3.948        3.948
# 18 1           0             985.600        0.000
# 19 1           1            1428.000     1428.000
# 20 1           1            4116.000     4116.000
# 21 1           1               3.696        3.696
# 22 1           1             884.800      884.800
# 23 1           0               2.492        0.000
# 24 1           1               5.936        5.936
# 25 1           1              10.248       10.248
# 26 1           1             229.600      229.600
# 27 1           0               2.716        0.000

# %%
dge <-
    DGEList(cnt_mtx) %>%
    calcNormFactors()

keep <- filterByExpr(dge, exp_model)
dge <- dge[keep,, keep.lib.sizes=FALSE]
vdge <- voom(dge, exp_model)
all_fit <- lmFit(vdge, exp_model) %>% eBayes

# %%
coefficients(all_fit)
# Out:
#          (Intercept) sample_typeT `Yield (ng)`  sample_typeT:`Yield (ng)`
# A2M       9.182881    0.2938167    8.425234e-04  3.778162e-04
# ACVR1C    7.820447   -1.1037032   -4.086683e-04 -2.846141e-04
# ADAM12    8.351144   -0.1639549    3.295049e-04  2.955234e-04
# ADGRE1    7.838257   -0.6703406   -9.183333e-04 -1.926161e-04
# ADM       8.262456   -0.4229190   -1.635368e-04  1.466006e-04
# ADORA2A   7.311179    0.1195144   -2.475449e-04 -3.330931e-04
# AKT1      8.655461    0.2292198    7.284833e-04  1.114073e-04
# ALDOA    10.304788    0.3893841    9.893617e-04  3.035706e-05
# ALDOC     8.065916    0.3034298    1.727255e-04 -3.607293e-04
# ANGPT1    7.757146   -0.6233283   -1.081692e-04  3.560098e-04
# ANGPT2    7.190809   -0.4891066    2.887259e-04  2.625216e-04
# ANGPTL4   8.195428   -0.7236622    2.629618e-04  3.284912e-04
# ANLN      7.198599    0.0182131    5.165615e-04  1.435518e-04
# APC       8.116706    0.3255503    4.670608e-04 -1.066499e-04
# APH1B     6.605005   -0.6499809   -1.777317e-04  7.742520e-05
# API5      8.806381    0.1217745    3.428137e-04  3.861762e-05
# APLNR     7.269756   -0.1727419    2.828051e-04  4.581347e-04
# APOE      9.335149    0.6543941    1.467026e-04  2.836898e-04
# APOL6     6.661694    1.0752032    8.341361e-05 -1.215602e-04
# AQP9      7.832390   -0.7673603   -6.512902e-04  4.247293e-05
# AREG      5.235979   -0.2463010   -7.836711e-05  2.448545e-04
# ARG1      7.204138   -0.9120807   -5.056714e-04 -3.752238e-05
# ARG2      7.752224   -0.6859964    7.539521e-05 -5.871464e-05
# ARID1A    7.544192    0.6706527    4.302534e-04 -1.924151e-04
# ARNT2     7.267702   -0.3429646    9.808310e-05 -1.525637e-04
# ATF3      8.265418   -0.3517762    1.181372e-04  1.578430e-04
# ATM       8.742502    0.3160627    4.060666e-04 -2.111978e-04
# AXIN1     7.035305   -0.3286269    2.840302e-04 -4.593804e-05
# AXL       7.537046    0.1059591    6.163271e-04  1.900540e-04
# B2M      11.722477    1.0229949    5.325806e-04 -8.018801e-05
# ⋮        ⋮           ⋮            ⋮             ⋮
# GUSB      7.797462    0.10067859   0.0004962416 -1.653234e-05
# MRPL19    8.125314   -0.58829254   0.0001939959  1.281440e-04
# NRDE2     7.409958    0.19724150   0.0002155134 -1.886314e-04
# OAZ1      8.822810    0.60967572   0.0006648785  7.503476e-05
# POLR2A    8.259475    0.49254653   0.0006839064  5.152687e-06
# PSMC4     7.973485   -0.15624029   0.0002041470  8.707359e-05
# PUM1      7.637217    0.63588349   0.0005088509 -1.751709e-04
# SDHA      7.942487    0.53562107   0.0005934739 -9.619504e-05
# SF3A1     7.860378    0.56799341   0.0005984079 -8.057214e-05
# STK11IP   6.957080   -0.42060809   0.0002715007 -1.153448e-05
# TBC1D10B  7.182348    0.17725612   0.0001912612  2.034469e-06
# TBP       7.574280   -0.15926605   0.0001815875 -5.569066e-05
# TFRC      8.777391    0.03026866   0.0003368795  1.980348e-04
# TLK2      7.872925   -0.38900670   0.0002796438  8.795670e-05
# TMUB2     8.007629   -0.03394620   0.0003934417 -8.932188e-05
# UBB      10.617136    0.59968138   0.0006468856  1.208114e-04
# NEG_A     7.715422   -0.81402450  -0.0012163910 -3.812270e-04
# NEG_B     5.860541   -0.96303822  -0.0009961970 -6.181959e-04
# NEG_C     5.165275   -0.41040024  -0.0008371344 -4.863841e-04
# NEG_D     4.974724    0.09607071  -0.0007561752 -3.331040e-04
# NEG_E     7.458400   -0.85341702  -0.0009792052 -3.335249e-04
# NEG_F     6.922557   -1.01706955  -0.0006658332 -4.133933e-04
# NEG_G     5.693922   -0.55696820  -0.0010041980 -2.424274e-04
# NEG_H     5.494040   -0.33430785  -0.0005490442 -6.723553e-04
# POS_A    18.976265   -0.62274341  -0.0010801523 -3.055659e-04
# POS_B    17.861904   -0.60606929  -0.0010874215 -3.235672e-04
# POS_C    15.827205   -0.65883342  -0.0011060681 -2.549751e-04
# POS_D    13.773693   -0.59738853  -0.0010484308 -2.522730e-04
# POS_E    11.464584   -0.36141097  -0.0010076631 -4.073775e-04
# POS_F    10.574178   -0.55991429  -0.0010412189 -4.738195e-04

# %%
all_table <-
    topTable(all_fit, adjust.method='fdr', n=nrow(cnt_mtx), sort.by='p', coef='sample_typeT') %>%
    rownames_to_column(var='gene_symbol') %>%
    as_tibble()

all_table %>%
    head(50)
# Out:
#    gene_symbol logFC      AveExpr   t         P.Value     adj.P.Val B
# 1  TTC30A      -1.1092562  7.427129 -3.614590 0.001113495 0.5349738 -3.717941
# 2  PF4         -1.3320694  5.836217 -3.429661 0.001814940 0.5349738 -3.960451
# 3  JAK3         1.6076228  7.884144  3.190199 0.003375420 0.5349738 -3.951230
# 4  GNG4        -1.5538750  6.224560 -3.057830 0.004724356 0.5349738 -4.041591
# 5  FGF9        -2.1524252  5.597828 -3.013427 0.005282107 0.5349738 -4.145564
# 6  CCL2         0.8379286  8.695009  2.984299 0.005681361 0.5349738 -3.966591
# 7  PGPEP1      -0.8452880  7.453079 -2.905040 0.006917518 0.5349738 -3.980892
# 8  FAM124B     -1.2248025  7.122810 -2.889405 0.007189650 0.5349738 -3.992099
# 9  TAP1         1.1939480  8.356301  2.822460 0.008473077 0.5349738 -4.058926
# 10 IL22RA1     -1.3921004  6.799257 -2.776062 0.009485805 0.5349738 -4.034477
# 11 SNCA        -0.9467946  7.540976 -2.754966 0.009982873 0.5349738 -4.020129
# 12 PTCD2       -1.0047273  7.489994 -2.733972 0.010501645 0.5349738 -4.015584
# 13 LILRA1      -0.8778329  6.813692 -2.714927 0.010993993 0.5349738 -4.086697
# 14 IL34        -0.9673768  7.251844 -2.625593 0.013604309 0.5349738 -4.107601
# 15 WNT2        -1.3707474  6.179489 -2.595735 0.014598020 0.5349738 -4.202888
# 16 GBP1         1.8089609  7.338022  2.594404 0.014643865 0.5349738 -4.196323
# 17 TAPBP        0.7718697  9.555559  2.571958 0.015437054 0.5349738 -4.052889
# 18 DTX4        -0.7155505  7.221387 -2.568150 0.015575482 0.5349738 -4.146432
# 19 TNFRSF10C   -0.8494738  6.523994 -2.556575 0.016003394 0.5349738 -4.189910
# 20 VTCN1       -1.1296973  6.420397 -2.551105 0.016209367 0.5349738 -4.175247
# 21 GLI1        -1.1432710  6.941097 -2.541071 0.016593590 0.5349738 -4.217741
# 22 MAPK10      -1.1430035  6.820717 -2.530951 0.016989579 0.5349738 -4.156727
# 23 MAGEA4      -1.3830996  5.725312 -2.482871 0.018992804 0.5349738 -4.259596
# 24 GBP2         0.9780609  8.346830  2.476355 0.019280445 0.5349738 -4.131776
# 25 MET         -1.0039625  7.730072 -2.423071 0.021786694 0.5349738 -4.173669
# 26 PARP9        0.9690283  7.712273  2.416789 0.022101071 0.5349738 -4.243255
# 27 IRF8         1.0849317  7.401887  2.414143 0.022234718 0.5349738 -4.193735
# 28 PRKAA2      -1.1206580  6.861445 -2.405335 0.022684953 0.5349738 -4.227736
# 29 CASP8        0.9174326  6.691394  2.403855 0.022761381 0.5349738 -4.276375
# 30 NKG7         1.1115994  7.754493  2.403432 0.022783281 0.5349738 -4.164915
# 31 CEACAM3     -1.1298350  5.994167 -2.397222 0.023106977 0.5349738 -4.257432
# 32 MAGEC1      -1.7107074  5.175440 -2.392037 0.023380447 0.5349738 -4.338526
# 33 CD45RO       1.4474996  8.070918  2.391415 0.023413463 0.5349738 -4.191966
# 34 GZMH        -1.0691186  6.370269 -2.382869 0.023871268 0.5349738 -4.253055
# 35 CD45RB       1.3376185  6.937207  2.382656 0.023882760 0.5349738 -4.241818
# 36 PRLR        -1.3190309  5.949045 -2.348799 0.025778528 0.5533503 -4.310467
# 37 B2M          1.0229949 12.897090  2.331235 0.026814975 0.5533503 -4.250419
# 38 IL24        -1.3909958  6.082909 -2.322894 0.027320337 0.5533503 -4.284279
# 39 TCL1A        2.0815896  6.190550  2.312310 0.027973967 0.5533503 -4.282058
# 40 CD79A        1.7590352  7.193588  2.308191 0.028232161 0.5533503 -4.225476
# 41 PPARG       -0.9774987  7.111228 -2.296091 0.029003196 0.5545977 -4.289415
# 42 HLA-B        1.0061880 12.710179  2.269704 0.030751034 0.5740193 -4.262730
# 43 GZMK         1.6324786  7.112214  2.256561 0.031656595 0.5771807 -4.269350
# 44 EDN1        -0.9303037  6.714151 -2.231600 0.033442875 0.5846158 -4.323137
# 45 MRPL19      -0.5882925  8.156000 -2.224716 0.033951211 0.5846158 -4.264966
# 46 CD45RA       1.5947979  5.936689  2.185510 0.036981009 0.5846158 -4.336683
# 47 CD27         1.1524891  7.107712  2.162785 0.038845949 0.5846158 -4.281232
# 48 CLEC4E      -1.1287115  6.534788 -2.162108 0.038902824 0.5846158 -4.295940
# 49 GPC4        -0.7834753  8.064703 -2.157956 0.039252934 0.5846158 -4.277076
# 50 TGFB2       -0.9698208  8.184769 -2.157716 0.039273211 0.5846158 -4.284781

# %%
all_table %>%
    mutate(
        `label`=case_when(
            abs(`logFC`) >= 2 ~ str_replace_all(`gene_symbol`, ',.*', ''),
            -log10(`P.Value`) > 2 ~ str_replace_all(`gene_symbol`, ',.*', ''),
            TRUE ~ ''
        )
    ) %>%
    ggplot(aes(x=`logFC`, y=-log10(`P.Value`))) +
        geom_point() +
        geom_vline(xintercept=0, color='gray') +
        geom_label_repel(aes(label=`label`), max.overlaps=Inf, force=10) +
        labs(
            x='Differential gene expression (log2 fold-change)',
            y='Significance (-log10(p.value))',
            title='DGE: Tumor vs Peritumor (corrected for RNA yield)'
        ) +
        xlim(-4, 4) +
        theme_bw(base_size=15) +
        theme(
            axis.text=element_text(size=12),
            axis.title=element_text(size=14),
            strip.text.x = element_text(size=15, face="bold"),
            plot.title = element_text(size=15, face="bold")
        )
# Out:
# plot without title

# %%
top_hits <-
    all_table %>%
    head(20) %>%
    pull(`gene_symbol`)

all_table %>%
    mutate(
        `label`=case_when(
            `gene_symbol` %in% top_hits ~ `gene_symbol`,
            TRUE ~ ''
        )
    ) %>%
    ggplot(aes(x=`logFC`, y=-log10(`P.Value`))) +
        geom_point() +
        geom_vline(xintercept=0, color='gray') +
        geom_label_repel(aes(label=`label`), max.overlaps=Inf, force=10) +
        labs(
            x='Differential gene expression (log2 fold-change)',
            y='Significance (-log10(p.value))',
            title='DGE: Tumor vs Peritumor (corrected for RNA yield)'
        ) +
        xlim(-4, 4) +
        theme_bw(base_size=15) +
        theme(
            axis.text=element_text(size=12),
            axis.title=element_text(size=14),
            strip.text.x = element_text(size=15, face="bold"),
            plot.title = element_text(size=15, face="bold")
        )
# Out:
# plot without title

# %%
genes_of_interest <-
    c('CD3E', 'CD3D', 'CD4', 'CD8A', 'CD8B', 'NCAM1')

# %%
all_table %>%
    mutate(
        `label`=case_when(
            `gene_symbol` %in% genes_of_interest ~ `gene_symbol`,
            TRUE ~ ''
        )
    ) %>%
    ggplot(aes(x=`logFC`, y=-log10(`P.Value`))) +
        geom_point() +
        geom_vline(xintercept=0, color='gray') +
        geom_point(
            data=. %>% filter(`gene_symbol` %in% genes_of_interest),
            size=3,
            color='maroon'
        ) +
        geom_label_repel(
            data=. %>% filter(`gene_symbol` %in% genes_of_interest),
            aes(label=`label`), max.overlaps=Inf, force=10,
            color='maroon'
        ) +
        labs(
            x='Differential gene expression (log2 fold-change)',
            y='Significance (-log10(p.value))',
            title='DGE: Tumor vs peritumor'
        ) +
        xlim(-4, 4) +
        theme_bw(base_size=15) +
        theme(
            axis.text=element_text(size=12),
            axis.title=element_text(size=14),
            strip.text.x = element_text(size=15, face="bold"),
            plot.title = element_text(size=15, face="bold")
        )
# Out:
# plot without title

# %%
all_table %>%
    mutate(
        `label`=case_when(
            startsWith(`gene_symbol`, 'POS_') ~ `gene_symbol`,
            startsWith(`gene_symbol`, 'NEG_') ~ `gene_symbol`,
            TRUE ~ ''
        )
    ) %>%
    ggplot(aes(x=`logFC`, y=-log10(`P.Value`))) +
        geom_point() +
        geom_vline(xintercept=0, color='gray') +
        geom_point(
            data=. %>% filter(`label` != ''),
            size=3,
            color='maroon'
        ) +
        geom_label_repel(
            data=. %>% filter(`label` != ''),
            aes(label=`label`), max.overlaps=Inf, force=10,
            color='maroon'
        ) +
        labs(
            x='Differential gene expression (log2 fold-change)',
            y='Significance (-log10(p.value))',
            title='DGE: Tumor vs peritumor (corrected for RNA yield)'
        ) +
        xlim(-4, 4) +
        theme_bw(base_size=15) +
        theme(
            axis.text=element_text(size=12),
            axis.title=element_text(size=14),
            strip.text.x = element_text(size=15, face="bold"),
            plot.title = element_text(size=15, face="bold")
        )
# Out:
# plot without title

# %%
all_table %>%
    mutate(
        `label`=case_when(
            startsWith(`gene_symbol`, 'COL') ~ `gene_symbol`,
            TRUE ~ ''
        )
    ) %>%
    ggplot(aes(x=`logFC`, y=-log10(`P.Value`))) +
        geom_point() +
        geom_vline(xintercept=0, color='gray') +
        geom_point(
            data=. %>% filter(`label` != ''),
            size=3,
            color='maroon'
        ) +
        geom_label_repel(
            data=. %>% filter(`label` != ''),
            aes(label=`label`), max.overlaps=Inf, force=10,
            color='maroon'
        ) +
        labs(
            x='Differential gene expression (log2 fold-change)',
            y='Significance (-log10(p.value))',
            title='DGE: Tumor vs peritumor'
        ) +
        xlim(-4, 4) +
        theme_bw(base_size=15) +
        theme(
            axis.text=element_text(size=12),
            axis.title=element_text(size=14),
            strip.text.x = element_text(size=15, face="bold"),
            plot.title = element_text(size=15, face="bold")
        )
# Out:
# plot without title
